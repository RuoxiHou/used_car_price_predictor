# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer
from category_encoders.target_encoder import TargetEncoder
from sklearn.compose import ColumnTransformer
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split,  KFold, cross_validate
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import pickle

# %%
offers = pd.read_csv('total_offers.csv')
offers.head()
# Out:
#          Make    Model         Trim  Year  Mileage(km)     kW Fuel type  \
# 0  Volkswagen   Sharan      2.0 tdi  2013       182000  104.0    Diesel
# 1        Audi       A6          2.7  2009       250000  141.0    Diesel
# 2     Porsche  Cayenne   3.0 diesel  2011       256000  182.0    Diesel
# 3  Volkswagen   Passat  2.0 tdi scr  2019        94187  111.0    Diesel
# 4  Volkswagen   Passat  2.0 tdi scr  2019        77167  111.0    Diesel
#
#   Body type   Color Transmission  Emission standard  Country            City  \
# 0       Van    Gray       Manual                  5  Austria  Braunau Am Inn
# 1     Sedan  Silver       Manual                  5  Austria        Salzburg
# 2       Suv   Black    Automatic                  5  Austria  Braunau Am Inn
# 3     Wagon  Silver       Manual                  6  Austria       Wolfsberg
# 4     Wagon   Black    Automatic                  6  Austria            Wels
#
#    Price(EUR)
# 0     15499.0
# 1      8900.0
# 2     25999.0
# 3     18790.0
# 4     18990.0

# %%
# Function to generate new numerical column based on compound score by make
def generate_sia_column(X, comp_score_make_dict_path):
    with open(comp_score_make_dict_path, 'rb') as f:
        comp_score_make_dict = pickle.load(f)
    X['SIA_Compound'] = X['Make'].apply(lambda x: comp_score_make_dict.get(x, 0))#replace the missing key with value 0 neutral
    return X

# %%
# Path to the pickle file containing the compound score by make dictionary
comp_score_make_dict_path = 'comp_score_make_dict.p'

# %%
X=offers.drop(columns=['Price(EUR)'])
y=offers['Price(EUR)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=10)

# %%
# Define numerical, one-hot encoded, and target encoded features
numerical_features = ['Year', 'Mileage(km)', 'kW', 'Emission standard', 'SIA_Compound']
onehot_features = ['Fuel type', 'Body type', 'Color', 'Transmission', 'Country']
target_features = ['Make', 'Model', 'Trim']

# Preprocessing steps for numerical features
numerical_transformer = SimpleImputer(strategy='mean')

# Preprocessing steps for one-hot encoded features
onehot_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Preprocessing steps for target encoded features
target_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('target_encoder', TargetEncoder())
])

# Combine preprocessing steps for numerical, one-hot encoded, and target encoded features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('onehot', onehot_transformer, onehot_features),
        ('target', target_transformer, target_features)
    ])

# Define the model
model = XGBRegressor()

# Construct the pipeline
pipeline = Pipeline(steps=[
    ('compound_score', FunctionTransformer(generate_sia_column, kw_args={'comp_score_make_dict_path': comp_score_make_dict_path})),
    ('preprocessor', preprocessor),
    ('model', model)
])

# Define hyperparameters for random search
param_grid = {
    'model__n_estimators': [50, 100, 200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000],
    'model__max_depth': [None, 2, 5, 10, 20, 30],
    'model__max_features': ['sqrt', 'log2'],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4],
    'model__bootstrap': [True, False]
}

# Define cross-validation strategy
kf = KFold(n_splits=5, shuffle=True, random_state=10)

# Randomized search for hyperparameter tuning
random_search = RandomizedSearchCV(estimator=pipeline, param_distributions=param_grid, n_iter=50, cv=kf, scoring='r2', verbose=2, n_jobs=10, random_state=10)
random_search.fit(X_train, y_train)

# Get the best model
best_model = random_search.best_estimator_

# Predict on the testing set
y_pred = best_model.predict(X_test)

# Evaluate the model
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("Testing R2 Score:", r2)
print("Testing Mean Squared Error:", mse)
print("Testing Mean Absolute Error:", mae)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# c:\Users\ruoxi\anaconda3\Lib\site-packages\xgboost\core.py:160: UserWarning: [22:31:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "bootstrap", "max_features", "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Testing R2 Score: 0.9064682426103239
# Testing Mean Squared Error: 49531099.3606752
# Testing Mean Absolute Error: 2083.9404441587617

# %%
random_search.best_score_
# Out:
# 0.8755126397179911

# %%
best_model
# Out:
# Pipeline(steps=[('compound_score',
#                  FunctionTransformer(func=<function generate_sia_column at 0x00000173CE50AAC0>,
#                                      kw_args={'comp_score_make_dict_path': 'comp_score_make_dict.p'})),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                                   ['Year', 'Mileage(km)', 'kW',
#                                                    'Emission standard',
#                                                    'SIA_Compound']),
#                                                  ('onehot',
#                                                   Pipeline(steps=[('imputer',
#                                                                    Simpl...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_features='log2',
#                               max_leaves=None, min_child_weight=None,
#                               min_samples_leaf=2, min_samples_split=10,
#                               missing=nan, monotone_constraints=None,
#                               multi_strategy=None, ...))])

# %%
best_model.get_params()
# Out:
# {'memory': None,
#  'steps': [('compound_score',
#    FunctionTransformer(func=<function generate_sia_column at 0x00000173CE50AAC0>,
#                        kw_args={'comp_score_make_dict_path': 'comp_score_make_dict.p'})),
#   ('preprocessor',
#    ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                     ['Year', 'Mileage(km)', 'kW',
#                                      'Emission standard', 'SIA_Compound']),
#                                    ('onehot',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('onehot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     ['Fuel type', 'Body type', 'Color',
#                                      'Transmission', 'Country']),
#                                    ('target',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('target_encoder',
#                                                      TargetEncoder())]),
#                                     ['Make', 'Model', 'Trim'])])),
#   ('model',
#    XGBRegressor(base_score=None, booster=None, bootstrap=False, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_features='log2',
#                 max_leaves=None, min_child_weight=None, min_samples_leaf=2,
#                 min_samples_split=10, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, ...))],
#  'verbose': False,
#  'compound_score': FunctionTransformer(func=<function generate_sia_column at 0x00000173CE50AAC0>,
#                      kw_args={'comp_score_make_dict_path': 'comp_score_make_dict.p'}),
#  'preprocessor': ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                   ['Year', 'Mileage(km)', 'kW',
#                                    'Emission standard', 'SIA_Compound']),
#                                  ('onehot',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('onehot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['Fuel type', 'Body type', 'Color',
#                                    'Transmission', 'Country']),
#                                  ('target',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('target_encoder',
#                                                    TargetEncoder())]),
#                                   ['Make', 'Model', 'Trim'])]),
#  'model': XGBRegressor(base_score=None, booster=None, bootstrap=False, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_features='log2',
#               max_leaves=None, min_child_weight=None, min_samples_leaf=2,
#               min_samples_split=10, missing=nan, monotone_constraints=None,
#               multi_strategy=None, ...),
#  'compound_score__accept_sparse': False,
#  'compound_score__check_inverse': True,
#  'compound_score__feature_names_out': None,
#  'compound_score__func': <function __main__.generate_sia_column(X, comp_score_make_dict_path)>,
#  'compound_score__inv_kw_args': None,
#  'compound_score__inverse_func': None,
#  'compound_score__kw_args': {'comp_score_make_dict_path': 'comp_score_make_dict.p'},
#  'compound_score__validate': False,
#  'preprocessor__n_jobs': None,
#  'preprocessor__remainder': 'drop',
#  'preprocessor__sparse_threshold': 0.3,
#  'preprocessor__transformer_weights': None,
#  'preprocessor__transformers': [('num',
#    SimpleImputer(),
#    ['Year', 'Mileage(km)', 'kW', 'Emission standard', 'SIA_Compound']),
#   ('onehot',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                    ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#    ['Fuel type', 'Body type', 'Color', 'Transmission', 'Country']),
#   ('target',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                    ('target_encoder', TargetEncoder())]),
#    ['Make', 'Model', 'Trim'])],
#  'preprocessor__verbose': False,
#  'preprocessor__verbose_feature_names_out': True,
#  'preprocessor__num': SimpleImputer(),
#  'preprocessor__onehot': Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#  'preprocessor__target': Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                  ('target_encoder', TargetEncoder())]),
#  'preprocessor__num__add_indicator': False,
#  'preprocessor__num__copy': True,
#  'preprocessor__num__fill_value': None,
#  'preprocessor__num__keep_empty_features': False,
#  'preprocessor__num__missing_values': nan,
#  'preprocessor__num__strategy': 'mean',
#  'preprocessor__onehot__memory': None,
#  'preprocessor__onehot__steps': [('imputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('onehot', OneHotEncoder(handle_unknown='ignore'))],
#  'preprocessor__onehot__verbose': False,
#  'preprocessor__onehot__imputer': SimpleImputer(strategy='most_frequent'),
#  'preprocessor__onehot__onehot': OneHotEncoder(handle_unknown='ignore'),
#  'preprocessor__onehot__imputer__add_indicator': False,
#  'preprocessor__onehot__imputer__copy': True,
#  'preprocessor__onehot__imputer__fill_value': None,
#  'preprocessor__onehot__imputer__keep_empty_features': False,
#  'preprocessor__onehot__imputer__missing_values': nan,
#  'preprocessor__onehot__imputer__strategy': 'most_frequent',
#  'preprocessor__onehot__onehot__categories': 'auto',
#  'preprocessor__onehot__onehot__drop': None,
#  'preprocessor__onehot__onehot__dtype': numpy.float64,
#  'preprocessor__onehot__onehot__feature_name_combiner': 'concat',
#  'preprocessor__onehot__onehot__handle_unknown': 'ignore',
#  'preprocessor__onehot__onehot__max_categories': None,
#  'preprocessor__onehot__onehot__min_frequency': None,
#  'preprocessor__onehot__onehot__sparse_output': True,
#  'preprocessor__target__memory': None,
#  'preprocessor__target__steps': [('imputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('target_encoder', TargetEncoder())],
#  'preprocessor__target__verbose': False,
#  'preprocessor__target__imputer': SimpleImputer(strategy='most_frequent'),
#  'preprocessor__target__target_encoder': TargetEncoder(),
#  'preprocessor__target__imputer__add_indicator': False,
#  'preprocessor__target__imputer__copy': True,
#  'preprocessor__target__imputer__fill_value': None,
#  'preprocessor__target__imputer__keep_empty_features': False,
#  'preprocessor__target__imputer__missing_values': nan,
#  'preprocessor__target__imputer__strategy': 'most_frequent',
#  'preprocessor__target__target_encoder__cols': None,
#  'preprocessor__target__target_encoder__drop_invariant': False,
#  'preprocessor__target__target_encoder__handle_missing': 'value',
#  'preprocessor__target__target_encoder__handle_unknown': 'value',
#  'preprocessor__target__target_encoder__hierarchy': None,
#  'preprocessor__target__target_encoder__min_samples_leaf': 20,
#  'preprocessor__target__target_encoder__return_df': True,
#  'preprocessor__target__target_encoder__smoothing': 10,
#  'preprocessor__target__target_encoder__verbose': 0,
#  'model__objective': 'reg:squarederror',
#  'model__base_score': None,
#  'model__booster': None,
#  'model__callbacks': None,
#  'model__colsample_bylevel': None,
#  'model__colsample_bynode': None,
#  'model__colsample_bytree': None,
#  'model__device': None,
#  'model__early_stopping_rounds': None,
#  'model__enable_categorical': False,
#  'model__eval_metric': None,
#  'model__feature_types': None,
#  'model__gamma': None,
#  'model__grow_policy': None,
#  'model__importance_type': None,
#  'model__interaction_constraints': None,
#  'model__learning_rate': None,
#  'model__max_bin': None,
#  'model__max_cat_threshold': None,
#  'model__max_cat_to_onehot': None,
#  'model__max_delta_step': None,
#  'model__max_depth': None,
#  'model__max_leaves': None,
#  'model__min_child_weight': None,
#  'model__missing': nan,
#  'model__monotone_constraints': None,
#  'model__multi_strategy': None,
#  'model__n_estimators': 800,
#  'model__n_jobs': None,
#  'model__num_parallel_tree': None,
#  'model__random_state': None,
#  'model__reg_alpha': None,
#  'model__reg_lambda': None,
#  'model__sampling_method': None,
#  'model__scale_pos_weight': None,
#  'model__subsample': None,
#  'model__tree_method': None,
#  'model__validate_parameters': None,
#  'model__verbosity': None,
#  'model__min_samples_split': 10,
#  'model__min_samples_leaf': 2,
#  'model__max_features': 'log2',
#  'model__bootstrap': False}

# %%
random_search.cv_results_
# Out:
# {'mean_fit_time': array([  0.76114888, 212.03101616, 308.17902679,  11.98297758,
#          27.41611147,   7.87049274,  16.42097898,  13.30639162,
#           8.69052434,   0.75988922,   1.61368494,   1.04235225,
#          25.96658864, 264.11741996,  81.61071339,   4.54558053,
#          17.70088081,   4.98906331,   0.51068115,   9.10585022,
#           1.39283261,  30.55401335,  72.94042621,   1.98096519,
#           0.88658547,   1.36095824,   4.2853385 , 193.65085063,
#          38.04117723,   4.21415019,   7.1600461 ,   2.78928246,
#          10.93866434,   0.3938971 ,   0.7666225 ,   1.81291018,
#           2.49830775,   6.12492967,   2.13121367,   5.43528819,
#           2.20277739, 290.80611429,   1.2709537 , 176.95692396,
#          92.91676497,   1.04770365,   1.59869437,  43.05525236,
#           0.37779512,   1.01209455]),
#  'std_fit_time': array([2.26424874e-02, 2.36322572e+01, 4.53700900e+01, 2.37277607e+00,
#         6.31221400e+00, 1.82790160e+00, 4.41583753e+00, 2.99149151e+00,
#         1.59491019e+00, 1.77649115e-01, 3.00700874e-01, 2.44270459e-01,
#         4.87201207e+00, 4.39695397e+01, 1.64151049e+01, 5.46117003e-02,
#         3.24586784e+00, 2.25228234e-01, 2.99762643e-02, 7.75727158e-01,
#         5.58803667e-02, 3.61499601e+00, 1.71739285e+01, 1.83663964e-01,
#         3.10987156e-02, 1.74965337e-01, 8.31384271e-01, 2.85606074e+01,
#         7.39296546e+00, 9.55225364e-01, 1.51217737e+00, 3.93990900e-01,
#         1.70081268e+00, 6.30123101e-03, 1.19169299e-01, 2.62010401e-01,
#         3.51488546e-01, 7.68095768e-01, 4.01797539e-01, 7.10321998e-01,
#         5.34635565e-01, 4.95007912e+01, 3.43016716e-02, 3.37580078e+01,
#         2.81767213e+01, 2.01034265e-01, 3.30212628e-01, 9.48324167e+00,
#         2.42668070e-02, 2.15761942e-01]),
#  'mean_score_time': array([ 0.16890025, 10.58954482, 16.17916012,  2.63862262,  2.66999207,
#          2.67232747,  3.880972  ,  0.27682252,  1.25195394,  0.07854981,
#          0.14613652,  0.05975342,  6.35301456, 12.18510194, 10.07694588,
#          1.70096784,  4.2907927 ,  0.3212501 ,  0.08278551,  3.11633921,
#          0.11508107,  3.04152908, 10.49434137,  0.1669795 ,  0.09221177,
#          0.11329761,  0.90030055, 10.89957995,  1.65918155,  0.27655263,
#          2.2734128 ,  0.28440738,  3.32190409,  0.05009084,  0.06356277,
#          0.1622663 ,  0.14806724,  1.72925401,  0.17842493,  1.83301306,
#          0.24926934, 15.49461789,  0.13764343,  7.66318364, 11.78598542,
#          0.09033055,  0.13541946,  3.2560081 ,  0.0718595 ,  0.07454901]),
#  'std_score_time': array([0.02039296, 2.72889002, 2.78608235, 0.55328831, 0.58643143,
#         0.45974633, 0.78018713, 0.0960568 , 0.51939183, 0.01962475,
#         0.03082038, 0.01287402, 1.23043514, 0.82421011, 1.42309926,
#         0.04216909, 0.72209215, 0.02400797, 0.01479588, 0.25352803,
#         0.01626206, 0.49961558, 2.78258736, 0.0188021 , 0.01579619,
#         0.02125332, 0.18715244, 2.74017077, 0.34832837, 0.04473731,
#         0.55795532, 0.05531098, 0.4179153 , 0.00343792, 0.00689969,
#         0.03108145, 0.02536746, 0.2564285 , 0.04104064, 0.35011093,
#         0.10659367, 3.19444606, 0.01764164, 0.44428463, 2.86968903,
#         0.02132363, 0.03203114, 1.02844267, 0.00633379, 0.00751284]),
#  'param_model__n_estimators': masked_array(data=[200, 1400, 2000, 800, 400, 2000, 1200, 50, 400, 100,
#                     1600, 50, 2000, 2000, 1400, 1600, 1200, 200, 50, 2000,
#                     50, 400, 1400, 1000, 400, 800, 800, 1400, 200, 200,
#                     1400, 2000, 1800, 50, 200, 400, 100, 1000, 1800, 1400,
#                     1800, 2000, 100, 1200, 2000, 800, 1200, 1000, 100, 200],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__min_samples_split': masked_array(data=[10, 2, 5, 2, 5, 10, 10, 5, 2, 2, 10, 5, 10, 5, 5, 2, 5,
#                     5, 10, 2, 5, 5, 2, 10, 10, 2, 10, 5, 5, 2, 5, 10, 2,
#                     10, 2, 5, 5, 5, 2, 2, 5, 5, 5, 5, 10, 2, 10, 2, 10, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__min_samples_leaf': masked_array(data=[4, 4, 4, 1, 4, 4, 4, 2, 2, 4, 2, 2, 4, 2, 1, 4, 4, 2,
#                     2, 2, 1, 1, 4, 2, 4, 2, 2, 4, 1, 4, 1, 1, 2, 2, 4, 2,
#                     4, 2, 2, 4, 2, 1, 1, 1, 2, 1, 4, 2, 1, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__max_features': masked_array(data=['sqrt', 'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'log2', 'log2', 'log2', 'sqrt', 'log2', 'log2', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'sqrt', 'sqrt', 'log2',
#                     'sqrt', 'sqrt', 'sqrt', 'log2', 'log2', 'log2', 'sqrt',
#                     'sqrt', 'log2', 'sqrt', 'log2', 'sqrt', 'log2', 'log2',
#                     'sqrt', 'log2', 'sqrt', 'log2', 'sqrt', 'log2', 'log2',
#                     'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2', 'log2', 'sqrt',
#                     'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__max_depth': masked_array(data=[2, 30, 30, 10, 20, 5, 10, 30, 10, None, 2, 10, 10, 30,
#                     20, 5, 10, 10, 5, 5, 10, 20, 20, 2, 2, 2, None, 30, 30,
#                     10, None, 2, None, None, 5, 5, 10, None, 2, 5, 2, 30,
#                     None, 30, 20, 2, 2, 20, 2, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__bootstrap': masked_array(data=[False, True, False, False, False, True, False, False,
#                     True, True, False, False, True, True, True, False,
#                     True, True, False, False, False, True, False, False,
#                     True, True, False, True, False, False, True, True,
#                     False, False, True, False, False, False, True, False,
#                     True, False, False, True, False, False, True, True,
#                     True, True],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'model__n_estimators': 200,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 2,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1400,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 30,
#    'model__bootstrap': True},
#   {'model__n_estimators': 2000,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 30,
#    'model__bootstrap': False},
#   {'model__n_estimators': 800,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': 10,
#    'model__bootstrap': False},
#   {'model__n_estimators': 400,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 20,
#    'model__bootstrap': False},
#   {'model__n_estimators': 2000,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 5,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1200,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 10,
#    'model__bootstrap': False},
#   {'model__n_estimators': 50,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 30,
#    'model__bootstrap': False},
#   {'model__n_estimators': 400,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 10,
#    'model__bootstrap': True},
#   {'model__n_estimators': 100,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1600,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 2,
#    'model__bootstrap': False},
#   {'model__n_estimators': 50,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 10,
#    'model__bootstrap': False},
#   {'model__n_estimators': 2000,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 10,
#    'model__bootstrap': True},
#   {'model__n_estimators': 2000,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 30,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1400,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': 20,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1600,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 5,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1200,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 10,
#    'model__bootstrap': True},
#   {'model__n_estimators': 200,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 10,
#    'model__bootstrap': True},
#   {'model__n_estimators': 50,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 5,
#    'model__bootstrap': False},
#   {'model__n_estimators': 2000,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 5,
#    'model__bootstrap': False},
#   {'model__n_estimators': 50,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': 10,
#    'model__bootstrap': False},
#   {'model__n_estimators': 400,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 20,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1400,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 20,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1000,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 2,
#    'model__bootstrap': False},
#   {'model__n_estimators': 400,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 2,
#    'model__bootstrap': True},
#   {'model__n_estimators': 800,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 2,
#    'model__bootstrap': True},
#   {'model__n_estimators': 800,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1400,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 30,
#    'model__bootstrap': True},
#   {'model__n_estimators': 200,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 30,
#    'model__bootstrap': False},
#   {'model__n_estimators': 200,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 10,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1400,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': None,
#    'model__bootstrap': True},
#   {'model__n_estimators': 2000,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': 2,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1800,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': None,
#    'model__bootstrap': False},
#   {'model__n_estimators': 50,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': False},
#   {'model__n_estimators': 200,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 5,
#    'model__bootstrap': True},
#   {'model__n_estimators': 400,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 5,
#    'model__bootstrap': False},
#   {'model__n_estimators': 100,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 10,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1000,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': None,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1800,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 2,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1400,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 5,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1800,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 2,
#    'model__bootstrap': True},
#   {'model__n_estimators': 2000,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': 30,
#    'model__bootstrap': False},
#   {'model__n_estimators': 100,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': None,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1200,
#    'model__min_samples_split': 5,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 30,
#    'model__bootstrap': True},
#   {'model__n_estimators': 2000,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 20,
#    'model__bootstrap': False},
#   {'model__n_estimators': 800,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 2,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1200,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 2,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1000,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 20,
#    'model__bootstrap': True},
#   {'model__n_estimators': 100,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 2,
#    'model__bootstrap': True},
#   {'model__n_estimators': 200,
#    'model__min_samples_split': 2,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': True}],
#  'split0_test_score': array([0.72526299, 0.73646257, 0.73646338, 0.745085  , 0.73789418,
#         0.75935923, 0.74508501, 0.73646414, 0.74508494, 0.74770633,
#         0.78391958, 0.74446065, 0.74508501, 0.73646338, 0.73789422,
#         0.75929918, 0.74508501, 0.74508764, 0.74598047, 0.75935923,
#         0.74446065, 0.73789418, 0.73789422, 0.77580536, 0.75631757,
#         0.77233139, 0.75027568, 0.73646257, 0.73646096, 0.74508764,
#         0.75028812, 0.78249175, 0.75029042, 0.74284542, 0.75702235,
#         0.75831531, 0.74496665, 0.7502568 , 0.78230731, 0.75928984,
#         0.78230731, 0.73646338, 0.74770633, 0.7364623 , 0.73789425,
#         0.77233139, 0.77898519, 0.7378942 , 0.70246756, 0.7495096 ]),
#  'split1_test_score': array([0.85865078, 0.82847838, 0.82847154, 0.85084713, 0.82744703,
#         0.90335016, 0.85084644, 0.82857254, 0.85084765, 0.902466  ,
#         0.88783772, 0.84991684, 0.85084505, 0.82847154, 0.82743698,
#         0.90338573, 0.85084644, 0.85085715, 0.8825219 , 0.90335016,
#         0.84991684, 0.82744703, 0.82743698, 0.88522318, 0.87395575,
#         0.88328354, 0.90773008, 0.82847838, 0.82849207, 0.85085715,
#         0.9077149 , 0.88827717, 0.90771194, 0.89516138, 0.89957882,
#         0.90203723, 0.8506387 , 0.90772587, 0.88749992, 0.90341256,
#         0.88749992, 0.82847154, 0.902466  , 0.82848066, 0.82743094,
#         0.88328354, 0.88609106, 0.827441  , 0.83912703, 0.90609029]),
#  'split2_test_score': array([0.89100466, 0.90380507, 0.90380502, 0.90945808, 0.9029662 ,
#         0.90913285, 0.9094581 , 0.90380027, 0.90945799, 0.92260584,
#         0.92094424, 0.90848175, 0.90945814, 0.90380502, 0.90296728,
#         0.9091192 , 0.9094581 , 0.90945846, 0.8926846 , 0.90913285,
#         0.90848175, 0.9029662 , 0.90296728, 0.91875882, 0.90681225,
#         0.91699407, 0.92762621, 0.90380507, 0.90380518, 0.90945846,
#         0.92763494, 0.92268578, 0.92763499, 0.91661113, 0.90563829,
#         0.90860635, 0.9093663 , 0.92763631, 0.92135922, 0.90921652,
#         0.92135922, 0.90380502, 0.92260584, 0.90380509, 0.90296793,
#         0.91699407, 0.92004059, 0.90296685, 0.87045387, 0.92686957]),
#  'split3_test_score': array([0.78812638, 0.76984381, 0.76984498, 0.78437214, 0.76447778,
#         0.84137929, 0.78437549, 0.76983926, 0.78436979, 0.84900833,
#         0.80471648, 0.78322443, 0.78438221, 0.76984498, 0.76448304,
#         0.84134902, 0.78437549, 0.78436217, 0.8194883 , 0.84137929,
#         0.78322443, 0.76447778, 0.76448304, 0.80016765, 0.79423924,
#         0.79864438, 0.85377583, 0.76984381, 0.76984145, 0.78436217,
#         0.8537468 , 0.80447529, 0.85374604, 0.83895503, 0.83699757,
#         0.83996221, 0.78422862, 0.85374816, 0.80466766, 0.84134114,
#         0.80466766, 0.76984498, 0.84900833, 0.76984341, 0.76448619,
#         0.79864438, 0.80124586, 0.76448093, 0.77725303, 0.85305939]),
#  'split4_test_score': array([0.90828944, 0.91206433, 0.91206462, 0.92215027, 0.9132555 ,
#         0.9369019 , 0.92215018, 0.91205953, 0.92215036, 0.93443224,
#         0.93603925, 0.92122269, 0.92215002, 0.91206462, 0.91325701,
#         0.93691564, 0.92215018, 0.92213792, 0.91602674, 0.9369019 ,
#         0.92122269, 0.9132555 , 0.91325701, 0.93170662, 0.92070208,
#         0.92859464, 0.9381554 , 0.91206433, 0.91206375, 0.92213792,
#         0.93814936, 0.93768951, 0.93814728, 0.92675931, 0.93403045,
#         0.93649854, 0.92215108, 0.93815276, 0.93727   , 0.93691395,
#         0.93727   , 0.91206462, 0.93443224, 0.91206423, 0.91325792,
#         0.92859464, 0.93373868, 0.91325641, 0.88954763, 0.93705788]),
#  'mean_test_score': array([0.83426685, 0.83013083, 0.83012991, 0.84238252, 0.82920814,
#         0.87002468, 0.84238304, 0.83014715, 0.84238215, 0.87124375,
#         0.86669145, 0.84146127, 0.84238408, 0.83012991, 0.82920771,
#         0.87001376, 0.84238304, 0.84238067, 0.8513404 , 0.87002468,
#         0.84146127, 0.82920814, 0.82920771, 0.86233232, 0.85040538,
#         0.85996961, 0.87551264, 0.83013083, 0.83013268, 0.84238067,
#         0.87550682, 0.8671239 , 0.87550613, 0.86406645, 0.8666535 ,
#         0.86908393, 0.84227027, 0.87550398, 0.86662082, 0.8700348 ,
#         0.86662082, 0.83012991, 0.87124375, 0.83013114, 0.82920745,
#         0.85996961, 0.86402028, 0.82920788, 0.81576983, 0.87451735]),
#  'std_test_score': array([0.06826988, 0.07007423, 0.0700739 , 0.068943  , 0.07076097,
#         0.06352952, 0.0689424 , 0.07007203, 0.06894343, 0.06835435,
#         0.06146825, 0.06888508, 0.0689412 , 0.0700739 , 0.07076062,
#         0.06355812, 0.0689424 , 0.0689414 , 0.06161367, 0.06352952,
#         0.06888508, 0.07076097, 0.07076062, 0.063043  , 0.06431972,
#         0.06316006, 0.06904301, 0.07007423, 0.07007489, 0.0689414 ,
#         0.06903914, 0.06261236, 0.0690377 , 0.06779875, 0.06331194,
#         0.0637345 , 0.0689778 , 0.06905226, 0.06224226, 0.06357653,
#         0.06224226, 0.0700739 , 0.06835435, 0.07007434, 0.07076042,
#         0.06316006, 0.0627019 , 0.07076076, 0.06826422, 0.06890037]),
#  'rank_test_score': array([35, 39, 41, 28, 44,  9, 26, 36, 29,  6, 14, 33, 25, 41, 47, 11, 26,
#         30, 23,  9, 33, 44, 47, 20, 24, 21,  1, 39, 37, 30,  2, 13,  3, 18,
#         15, 12, 32,  4, 16,  8, 16, 41,  6, 38, 49, 21, 19, 46, 50,  5])}

# %%
random_search.best_params_
# Out:
# {'model__n_estimators': 800,
#  'model__min_samples_split': 10,
#  'model__min_samples_leaf': 2,
#  'model__max_features': 'log2',
#  'model__max_depth': None,
#  'model__bootstrap': False}

# %% [markdown]
# The scores are much better than the XGB Regressor model without SIA compound score. Try another roound of random search

# %%
# Define numerical, one-hot encoded, and target encoded features
numerical_features = ['Year', 'Mileage(km)', 'kW', 'Emission standard', 'SIA_Compound']
onehot_features = ['Fuel type', 'Body type', 'Color', 'Transmission', 'Country']
target_features = ['Make', 'Model', 'Trim']

# Preprocessing steps for numerical features
numerical_transformer = SimpleImputer(strategy='mean')

# Preprocessing steps for one-hot encoded features
onehot_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Preprocessing steps for target encoded features
target_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('target_encoder', TargetEncoder())
])

# Combine preprocessing steps for numerical, one-hot encoded, and target encoded features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('onehot', onehot_transformer, onehot_features),
        ('target', target_transformer, target_features)
    ])

# Define the model
model = XGBRegressor()

# Construct the pipeline
pipeline = Pipeline(steps=[
    ('compound_score', FunctionTransformer(generate_sia_column, kw_args={'comp_score_make_dict_path': comp_score_make_dict_path})),
    ('preprocessor', preprocessor),
    ('model', model)
])

# Define hyperparameters for random search
param_grid = {
    'model__n_estimators': [80, 150, 300, 500, 700, 900, 1100, 1300, 1500, 1600, 1700, 1900],
    'model__max_depth': [None, 1, 3, 4, 5, 6, 7, 8, 9],
    'model__max_features': ['sqrt', 'log2'],
    'model__min_samples_split': [8, 9, 10, 11, 12, 13],
    'model__min_samples_leaf': [1, 2, 3, 4, 5],
    'model__bootstrap': [True, False]
}

# Define cross-validation strategy
kf = KFold(n_splits=5, shuffle=True, random_state=10)

# Randomized search for hyperparameter tuning
random_search = RandomizedSearchCV(estimator=pipeline, param_distributions=param_grid, n_iter=50, cv=kf, scoring='r2', verbose=2, n_jobs=10, random_state=10)
random_search.fit(X_train, y_train)

# Get the best model
best_model = random_search.best_estimator_

# Predict on the testing set
y_pred = best_model.predict(X_test)

# Evaluate the model
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("Testing R2 Score:", r2)
print("Testing Mean Squared Error:", mse)
print("Testing Mean Absolute Error:", mae)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# c:\Users\ruoxi\anaconda3\Lib\site-packages\xgboost\core.py:160: UserWarning: [22:51:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "bootstrap", "max_features", "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Testing R2 Score: 0.9065224658426563
# Testing Mean Squared Error: 49502384.661162734
# Testing Mean Absolute Error: 2057.6936190042184

# %%
random_search.best_score_
# Out:
# 0.8755073975445711

# %%
random_search.best_params_
# Out:
# {'model__n_estimators': 1300,
#  'model__min_samples_split': 13,
#  'model__min_samples_leaf': 4,
#  'model__max_features': 'sqrt',
#  'model__max_depth': None,
#  'model__bootstrap': True}

# %%
random_search.cv_results_
# Out:
# {'mean_fit_time': array([ 0.8065064 ,  2.3572485 , 14.01219258,  0.35058684, 11.16539378,
#          1.08239474,  0.51136556,  0.75571785,  7.08847771,  2.15043378,
#          0.92235527,  7.65541625,  3.42270269,  0.58553615,  9.13774257,
#         10.78446856,  1.27674341, 10.78420806,  0.9214365 , 10.56009545,
#          2.54546328,  0.51179662,  4.06323524, 13.81395969,  1.02019787,
#          8.83646431,  1.77891259,  3.23536296,  2.4904798 , 10.67101502,
#          2.44238825, 10.06065369,  0.66640944,  0.32756963,  3.60083838,
#          6.86123939,  1.65527134,  3.42241321,  0.33687472,  0.35219994,
#          0.28663321,  1.09247236,  5.91562953, 14.48415413,  1.1880024 ,
#          1.53593459,  5.95104704,  0.64569111,  8.33522544,  4.13838811]),
#  'std_fit_time': array([0.09896089, 0.04330435, 2.78031779, 0.0363704 , 0.1100633 ,
#         0.21900266, 0.07586786, 0.12551829, 1.15891338, 0.46760692,
#         0.2000938 , 1.60475587, 0.67637912, 0.10851408, 1.99127474,
#         1.4471322 , 0.00527825, 2.05315615, 0.03209847, 0.80370998,
#         0.4952224 , 0.00672282, 0.75965891, 2.52438251, 0.20150819,
#         1.76765365, 0.05024169, 0.62529293, 0.43477786, 2.33189994,
#         0.31727524, 1.52983684, 0.01146172, 0.00797708, 0.62681888,
#         1.49242934, 0.04065655, 0.51402433, 0.06563288, 0.06857774,
#         0.04186699, 0.19878571, 0.89628584, 2.35847039, 0.04027201,
#         0.31759325, 1.23106925, 0.04417025, 0.2394135 , 0.28187522]),
#  'mean_score_time': array([0.08439832, 0.16489291, 2.96924915, 0.08151336, 2.25623288,
#         0.08895736, 0.05805793, 0.07398186, 1.74241109, 0.1857235 ,
#         0.07402563, 2.59900761, 0.54129815, 0.07890639, 2.03406196,
#         2.42632546, 0.09706287, 2.6441134 , 0.0850997 , 3.04209905,
#         0.28877168, 0.06239934, 1.40993023, 3.57964444, 0.09224343,
#         2.49366007, 0.16275654, 1.02660413, 0.1749896 , 2.33122478,
#         0.15083327, 2.83766441, 0.05474033, 0.04281578, 0.72879176,
#         2.07337537, 0.15290637, 0.25502   , 0.0494575 , 0.05519824,
#         0.04816055, 0.10587091, 1.8940424 , 3.76863766, 0.10583215,
#         0.1160326 , 1.7941515 , 0.05956812, 1.61325622, 0.28613591]),
#  'std_score_time': array([0.02935836, 0.02209568, 0.1146441 , 0.0119331 , 0.03945585,
#         0.0230918 , 0.01271281, 0.01765103, 0.19797867, 0.0421795 ,
#         0.01346086, 0.71023236, 0.19854965, 0.02300153, 0.44165118,
#         0.36407242, 0.00656111, 0.51166249, 0.02162191, 0.42843708,
#         0.06536011, 0.00542242, 0.31336828, 0.6124353 , 0.01766185,
#         0.37712866, 0.00732332, 0.23349539, 0.03630989, 0.43580046,
#         0.01705806, 0.51980625, 0.00685303, 0.00498857, 0.20539246,
#         0.44685987, 0.01798822, 0.06316792, 0.00638095, 0.01378219,
#         0.01160379, 0.02538531, 0.3927935 , 0.54543387, 0.0064276 ,
#         0.03560535, 0.406565  , 0.01106648, 0.63758438, 0.08258387]),
#  'param_model__n_estimators': masked_array(data=[900, 1600, 1900, 80, 900, 1300, 80, 150, 900, 1500,
#                     150, 1700, 1500, 150, 700, 700, 300, 1500, 80, 1900,
#                     1300, 300, 1500, 1900, 1100, 1700, 1500, 1700, 300,
#                     900, 150, 1900, 150, 300, 900, 1500, 1700, 300, 150,
#                     80, 150, 700, 1300, 1700, 900, 300, 1300, 300, 1500,
#                     500],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__min_samples_split': masked_array(data=[13, 9, 13, 12, 11, 9, 9, 12, 8, 8, 13, 8, 8, 8, 13, 9,
#                     9, 10, 13, 9, 13, 9, 10, 10, 9, 13, 11, 9, 9, 12, 13,
#                     12, 12, 11, 8, 11, 13, 11, 8, 11, 8, 10, 13, 12, 8, 13,
#                     8, 13, 12, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__min_samples_leaf': masked_array(data=[3, 2, 3, 4, 2, 2, 1, 2, 3, 2, 1, 3, 4, 5, 4, 2, 5, 4,
#                     2, 4, 4, 5, 3, 2, 2, 3, 2, 3, 3, 2, 1, 1, 1, 5, 5, 5,
#                     4, 3, 1, 3, 5, 1, 4, 4, 1, 3, 4, 2, 3, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__max_features': masked_array(data=['log2', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'sqrt', 'log2', 'sqrt', 'sqrt', 'sqrt', 'log2', 'log2',
#                     'log2', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'log2', 'log2', 'sqrt', 'sqrt', 'log2', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'log2', 'log2', 'log2',
#                     'sqrt', 'log2', 'log2', 'log2', 'log2', 'sqrt', 'log2',
#                     'sqrt', 'sqrt', 'log2', 'log2', 'log2', 'log2', 'sqrt',
#                     'sqrt'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__max_depth': masked_array(data=[1, 1, 9, 1, 8, 1, 5, 6, 7, 3, 6, 6, 4, 4, 9, 9, 6, 8,
#                     7, None, 4, 3, 5, 8, 1, None, 3, 4, 7, 9, 9, None,
#                     None, 1, None, 6, 1, 8, 3, 4, 1, 3, None, 8, 3, 6,
#                     None, 4, 7, 7],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_model__bootstrap': masked_array(data=[True, False, False, True, False, False, False, False,
#                     True, True, False, False, False, False, True, False,
#                     False, True, True, True, True, True, True, False,
#                     False, True, False, False, False, False, False, False,
#                     True, True, True, True, True, False, False, True,
#                     False, True, True, False, False, False, False, True,
#                     False, True],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'model__n_estimators': 900,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 1,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1600,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 1,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1900,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 9,
#    'model__bootstrap': False},
#   {'model__n_estimators': 80,
#    'model__min_samples_split': 12,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 1,
#    'model__bootstrap': True},
#   {'model__n_estimators': 900,
#    'model__min_samples_split': 11,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 8,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1300,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 1,
#    'model__bootstrap': False},
#   {'model__n_estimators': 80,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 5,
#    'model__bootstrap': False},
#   {'model__n_estimators': 150,
#    'model__min_samples_split': 12,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 6,
#    'model__bootstrap': False},
#   {'model__n_estimators': 900,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 7,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1500,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 3,
#    'model__bootstrap': True},
#   {'model__n_estimators': 150,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 6,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1700,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 6,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1500,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 4,
#    'model__bootstrap': False},
#   {'model__n_estimators': 150,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 5,
#    'model__max_features': 'log2',
#    'model__max_depth': 4,
#    'model__bootstrap': False},
#   {'model__n_estimators': 700,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 9,
#    'model__bootstrap': True},
#   {'model__n_estimators': 700,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 9,
#    'model__bootstrap': False},
#   {'model__n_estimators': 300,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 5,
#    'model__max_features': 'log2',
#    'model__max_depth': 6,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1500,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 8,
#    'model__bootstrap': True},
#   {'model__n_estimators': 80,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 7,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1900,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': None,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1300,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 4,
#    'model__bootstrap': True},
#   {'model__n_estimators': 300,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 5,
#    'model__max_features': 'log2',
#    'model__max_depth': 3,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1500,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 5,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1900,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 8,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1100,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 1,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1700,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1500,
#    'model__min_samples_split': 11,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 3,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1700,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 4,
#    'model__bootstrap': False},
#   {'model__n_estimators': 300,
#    'model__min_samples_split': 9,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 7,
#    'model__bootstrap': False},
#   {'model__n_estimators': 900,
#    'model__min_samples_split': 12,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 9,
#    'model__bootstrap': False},
#   {'model__n_estimators': 150,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 9,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1900,
#    'model__min_samples_split': 12,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': False},
#   {'model__n_estimators': 150,
#    'model__min_samples_split': 12,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': True},
#   {'model__n_estimators': 300,
#    'model__min_samples_split': 11,
#    'model__min_samples_leaf': 5,
#    'model__max_features': 'log2',
#    'model__max_depth': 1,
#    'model__bootstrap': True},
#   {'model__n_estimators': 900,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 5,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1500,
#    'model__min_samples_split': 11,
#    'model__min_samples_leaf': 5,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 6,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1700,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': 1,
#    'model__bootstrap': True},
#   {'model__n_estimators': 300,
#    'model__min_samples_split': 11,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 8,
#    'model__bootstrap': False},
#   {'model__n_estimators': 150,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': 3,
#    'model__bootstrap': False},
#   {'model__n_estimators': 80,
#    'model__min_samples_split': 11,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 4,
#    'model__bootstrap': True},
#   {'model__n_estimators': 150,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 5,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 1,
#    'model__bootstrap': False},
#   {'model__n_estimators': 700,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': 3,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1300,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': None,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1700,
#    'model__min_samples_split': 12,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 8,
#    'model__bootstrap': False},
#   {'model__n_estimators': 900,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 1,
#    'model__max_features': 'log2',
#    'model__max_depth': 3,
#    'model__bootstrap': False},
#   {'model__n_estimators': 300,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'log2',
#    'model__max_depth': 6,
#    'model__bootstrap': False},
#   {'model__n_estimators': 1300,
#    'model__min_samples_split': 8,
#    'model__min_samples_leaf': 4,
#    'model__max_features': 'log2',
#    'model__max_depth': None,
#    'model__bootstrap': False},
#   {'model__n_estimators': 300,
#    'model__min_samples_split': 13,
#    'model__min_samples_leaf': 2,
#    'model__max_features': 'log2',
#    'model__max_depth': 4,
#    'model__bootstrap': True},
#   {'model__n_estimators': 1500,
#    'model__min_samples_split': 12,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 7,
#    'model__bootstrap': False},
#   {'model__n_estimators': 500,
#    'model__min_samples_split': 10,
#    'model__min_samples_leaf': 3,
#    'model__max_features': 'sqrt',
#    'model__max_depth': 7,
#    'model__bootstrap': True}],
#  'split0_test_score': array([0.65452869, 0.66208662, 0.72918757, 0.6005538 , 0.73513372,
#         0.65963373, 0.75150955, 0.74885337, 0.71618776, 0.72723041,
#         0.74885337, 0.75029049, 0.74023848, 0.74123753, 0.72919561,
#         0.72919561, 0.74967059, 0.73513433, 0.71326575, 0.75029054,
#         0.73987821, 0.7154337 , 0.75929908, 0.73513422, 0.65794493,
#         0.75029049, 0.72723041, 0.74018522, 0.71613458, 0.72919439,
#         0.72905867, 0.75029054, 0.74885337, 0.63117293, 0.75026455,
#         0.75028775, 0.6625723 , 0.73510333, 0.70652309, 0.73857211,
#         0.61458274, 0.72110627, 0.75028908, 0.73513431, 0.72151511,
#         0.74967059, 0.75028908, 0.73931279, 0.71618938, 0.71622933]),
#  'split1_test_score': array([0.66721214, 0.66990279, 0.86314647, 0.63561463, 0.85711149,
#         0.66918405, 0.8917602 , 0.90431887, 0.8696625 , 0.90286774,
#         0.90431887, 0.90771238, 0.92639853, 0.91596136, 0.86314673,
#         0.86314673, 0.90773388, 0.85711153, 0.86566812, 0.90771229,
#         0.92631363, 0.89226454, 0.90341361, 0.85711153, 0.66772322,
#         0.90771238, 0.90286774, 0.92636505, 0.869724  , 0.86314672,
#         0.86309878, 0.90771229, 0.90431887, 0.6514399 , 0.90772871,
#         0.90771408, 0.67038257, 0.85708476, 0.88440907, 0.90722702,
#         0.63826182, 0.89900069, 0.90771433, 0.85711153, 0.90081952,
#         0.90773388, 0.90771433, 0.92181386, 0.8696624 , 0.86971685]),
#  'split2_test_score': array([0.79024141, 0.80045993, 0.91677249, 0.73594696, 0.92007223,
#         0.79668018, 0.89826513, 0.92602225, 0.92723382, 0.92570147,
#         0.92602225, 0.92763589, 0.9249629 , 0.91372796, 0.91677248,
#         0.91677248, 0.92729726, 0.9200722 , 0.92217468, 0.92763502,
#         0.92488358, 0.91196076, 0.90916727, 0.92007227, 0.79370046,
#         0.92763589, 0.92570147, 0.92500556, 0.92720532, 0.91677249,
#         0.91655161, 0.92763502, 0.92602225, 0.7699162 , 0.92763664,
#         0.92763555, 0.80165099, 0.92006989, 0.90224537, 0.90734018,
#         0.75533589, 0.92045879, 0.92763151, 0.92007224, 0.92181577,
#         0.92729726, 0.92763151, 0.9206671 , 0.92723306, 0.92723852]),
#  'split3_test_score': array([0.73435565, 0.7399309 , 0.82532868, 0.71013134, 0.80992441,
#         0.73793325, 0.82695283, 0.85194065, 0.81155396, 0.85043312,
#         0.85194065, 0.85374741, 0.85259226, 0.83758691, 0.82532841,
#         0.82532841, 0.85405713, 0.8099245 , 0.80888015, 0.85374551,
#         0.85228569, 0.83613673, 0.84134036, 0.80992442, 0.73682089,
#         0.85374741, 0.85043312, 0.85267392, 0.81117072, 0.82532845,
#         0.82522177, 0.85374551, 0.85194065, 0.72788232, 0.85375263,
#         0.85374698, 0.74027893, 0.80983984, 0.82357034, 0.82606557,
#         0.72136417, 0.84608683, 0.85375185, 0.80992446, 0.84877992,
#         0.85405713, 0.85375185, 0.84614016, 0.81155385, 0.81148829]),
#  'split4_test_score': array([0.83686796, 0.84537835, 0.9127599 , 0.80380109, 0.92401438,
#         0.84242848, 0.92626714, 0.93651844, 0.93482871, 0.94397771,
#         0.93651844, 0.9381464 , 0.92930121, 0.91460168, 0.91275997,
#         0.91275997, 0.93783107, 0.92401383, 0.93163314, 0.93814684,
#         0.92914892, 0.93181135, 0.93691683, 0.92401326, 0.83968763,
#         0.9381464 , 0.94397771, 0.92932631, 0.93471055, 0.9127599 ,
#         0.91273586, 0.93814684, 0.93651844, 0.82093063, 0.93815351,
#         0.93814789, 0.8461627 , 0.92399962, 0.92029959, 0.90542175,
#         0.81268665, 0.94075249, 0.93815021, 0.92401354, 0.94171883,
#         0.93783107, 0.93815021, 0.92420264, 0.9348298 , 0.9348048 ]),
#  'mean_test_score': array([0.73664117, 0.74355172, 0.84943902, 0.69720956, 0.84925125,
#         0.74117194, 0.85895097, 0.87353072, 0.85189335, 0.87004209,
#         0.87353072, 0.87550651, 0.87469868, 0.86462309, 0.84944064,
#         0.84944064, 0.87531798, 0.84925128, 0.84832437, 0.87550604,
#         0.874502  , 0.85752142, 0.87002743, 0.84925114, 0.73917543,
#         0.87550651, 0.87004209, 0.87471121, 0.85178903, 0.84944039,
#         0.84933334, 0.87550604, 0.87353072, 0.72026839, 0.87550721,
#         0.87550645, 0.7442095 , 0.84921949, 0.84740949, 0.85692533,
#         0.70844625, 0.86548101, 0.8755074 , 0.84925122, 0.86692983,
#         0.87531798, 0.8755074 , 0.87042731, 0.8518937 , 0.85189556]),
#  'std_test_score': array([0.06998067, 0.07166735, 0.06895353, 0.07234028, 0.07104412,
#         0.07095812, 0.06280296, 0.06882049, 0.08113381, 0.07800212,
#         0.06882049, 0.06903761, 0.07314238, 0.06855613, 0.06895076,
#         0.06895076, 0.06913727, 0.07104379, 0.08061229, 0.06903765,
#         0.07324775, 0.07789216, 0.06356803, 0.07104373, 0.07040602,
#         0.06903761, 0.07800212, 0.07316192, 0.08116309, 0.06895117,
#         0.06895654, 0.06903765, 0.06882049, 0.07117742, 0.06904961,
#         0.06903901, 0.07186721, 0.07105908, 0.07759664, 0.06690834,
#         0.07344084, 0.07878086, 0.06903805, 0.07104375, 0.07903067,
#         0.06913727, 0.06903805, 0.07188502, 0.08113336, 0.08112481]),
#  'rank_test_score': array([47, 44, 34, 50, 37, 45, 24, 14, 29, 18, 14,  4, 12, 23, 31, 31,  9,
#         36, 41,  7, 13, 25, 20, 39, 46,  4, 18, 11, 30, 33, 35,  7, 14, 48,
#          3,  6, 43, 40, 42, 26, 49, 22,  1, 38, 21,  9,  1, 17, 28, 27])}

# %% [markdown]
# The performance is not improved. Next, narrow down the hyperparameters by using Grid search

# %%
# Define numerical, one-hot encoded, and target encoded features
numerical_features = ['Year', 'Mileage(km)', 'kW', 'Emission standard', 'SIA_Compound']
onehot_features = ['Fuel type', 'Body type', 'Color', 'Transmission', 'Country']
target_features = ['Make', 'Model', 'Trim']

# Preprocessing steps for numerical features
numerical_transformer = SimpleImputer(strategy='mean')

# Preprocessing steps for one-hot encoded features
onehot_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Preprocessing steps for target encoded features
target_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('target_encoder', TargetEncoder())
])

# Combine preprocessing steps for numerical, one-hot encoded, and target encoded features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('onehot', onehot_transformer, onehot_features),
        ('target', target_transformer, target_features)
    ])

# Define the model
model = XGBRegressor()

# Construct the pipeline
pipeline = Pipeline(steps=[
    ('compound_score', FunctionTransformer(generate_sia_column, kw_args={'comp_score_make_dict_path': comp_score_make_dict_path})),
    ('preprocessor', preprocessor),
    ('model', model)
])

# Define hyperparameters for random search
param_grid = {
    'model__n_estimators': [800, 850, 950, 1050, 1150, 1250, 1300],
    'model__max_depth': [None, 1, 2],
    'model__max_features': ['sqrt', 'log2'],
    'model__min_samples_split': [10, 13],
    'model__min_samples_leaf': [2, 4],
    'model__bootstrap': [True, False]
}

# Define cross-validation strategy
kf = KFold(n_splits=5, shuffle=True, random_state=10)

# Randomized search for hyperparameter tuning
grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=kf, n_jobs=10)
grid_search.fit(X_train, y_train)

# Get the best model
best_model_grid = grid_search.best_estimator_

# Predict on the testing set
y_pred = best_model_grid.predict(X_test)

# Evaluate the model
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("Testing R2 Score:", r2)
print("Testing Mean Squared Error:", mse)
print("Testing Mean Absolute Error:", mae)
# Out:
# c:\Users\ruoxi\anaconda3\Lib\site-packages\xgboost\core.py:160: UserWarning: [23:06:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "bootstrap", "max_features", "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Testing R2 Score: 0.9064682426103239
# Testing Mean Squared Error: 49531099.3606752
# Testing Mean Absolute Error: 2083.9404441587617

# %%
grid_search.best_score_
# Out:
# 0.8755126397179911

# %%
grid_search.best_params_
# Out:
# {'model__bootstrap': True,
#  'model__max_depth': None,
#  'model__max_features': 'sqrt',
#  'model__min_samples_leaf': 2,
#  'model__min_samples_split': 10,
#  'model__n_estimators': 800}

# %% [markdown]
# The performance is not better than the model without SIA compound score
