# %%
import pandas as pd
import re

# %%
# List to store rearranged dataframes
rearranged_dfs = []

# %%
column_names= ['Make', 'Model', 'Trim', 'Year', 'Mileage(km)', 'kW', 'Fuel type', 'Body type', 'Color', 'Transmission', 'Emission standard', 'Contact', 'Country', 'City', 'Price(EUR)']

# %%
as_offers = pd.read_csv('cleaned_Austria_offers.csv')

# %%
be_offers = pd.read_csv('cleaned_Belgium_offers.csv')
cr_offers = pd.read_csv('cleaned_Czech_offers.csv')
dm_offers= pd.read_csv('cleaned_Denmark_offers.csv')
fr_offers = pd.read_csv('cleaned_France_offers.csv')
gr_offers= pd.read_csv('cleaned_Germany_offers.csv')
hg_offers = pd.read_csv('cleaned_Hungary_offers.csv')
it_offers = pd.read_csv('cleaned_Italy_offers.csv')
nl_offers= pd.read_csv('cleaned_Netherlands_offers.csv')
nw_offers = pd.read_csv('cleaned_Norway_offers.csv')
pl_offers = pd.read_csv('cleaned_Poland_offers.csv')
pt_offers = pd.read_csv('cleaned_Portugal_offers.csv')
rm_offers = pd.read_csv('cleaned_Romania_offers.csv')
sp_offers = pd.read_csv('cleaned_Spain_offers.csv')
st_offers = pd.read_csv('cleaned_Switzerland_offers.csv')
sd_offers = pd.read_csv('cleaned_Sweden_offers.csv')

# %%
# Iterate over each dataframe and rearrange columns
for df in [as_offers, be_offers, cr_offers, dm_offers, fr_offers, gr_offers, hg_offers, it_offers, nl_offers, nw_offers, pl_offers, pt_offers, rm_offers, sp_offers, st_offers, sd_offers]:
    rearranged_df = df[column_names]  # Rearrange columns according to the desired order
    rearranged_dfs.append(rearranged_df)

# %%
# Concatenate the rearranged dataframes
concatenated_df = pd.concat(rearranged_dfs, ignore_index=True)

# %%
concatenated_df.shape
# Out:
# (3279, 15)

# %%
concatenated_df.head()
# Out:
#          Make    Model         Trim  Year  Mileage(km)     kW Fuel type  \
# 0  Volkswagen   Sharan      2.0 TDI  2013       182000  104.0    Diesel
# 1        Audi       A6          2.7  2009       250000  141.0    Diesel
# 2     Porsche  Cayenne   3.0 diesel  2011       256000  182.0    Diesel
# 3  Volkswagen   Passat  2.0 TDI SCR  2019        94187  111.0    Diesel
# 4  Volkswagen   Passat  2.0 TDI SCR  2019        77167  111.0    Diesel
#
#   Body type   Color Transmission  Emission standard  \
# 0       Van    Gray       Manual                  5
# 1     Sedan  Silver       Manual                  5
# 2       Suv   Black    Automatic                  5
# 3     Wagon  Silver       Manual                  6
# 4     Wagon   Black    Automatic                  6
#
#                                              Contact  Country            City  \
# 0  https://www.zweispurig.at/vw-sharan-gebrauchtw...  Austria  Braunau Am Inn
# 1  https://www.zweispurig.at/audi-a6-gebrauchtwag...  Austria        Salzburg
# 2  https://www.zweispurig.at/porsche-cayenne-gebr...  Austria  Braunau Am Inn
# 3  https://www.zweispurig.at/vw-passat-gebrauchtw...  Austria       Wolfsberg
# 4      https://www.dasweltauto.at/vehicle/4633600081  Austria            Wels
#
#    Price(EUR)
# 0     15499.0
# 1      8900.0
# 2     25999.0
# 3     18790.0
# 4     18990.0

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3279 entries, 0 to 3278
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               3279 non-null   object
#  1   Model              3279 non-null   object
#  2   Trim               3279 non-null   object
#  3   Year               3279 non-null   int64
#  4   Mileage(km)        3279 non-null   int64
#  5   kW                 3279 non-null   float64
#  6   Fuel type          3279 non-null   object
#  7   Body type          3279 non-null   object
#  8   Color              3179 non-null   object
#  9   Transmission       3279 non-null   object
#  10  Emission standard  3279 non-null   int64
#  11  Contact            3279 non-null   object
#  12  Country            3279 non-null   object
#  13  City               3136 non-null   object
#  14  Price(EUR)         3279 non-null   float64
# dtypes: float64(2), int64(3), object(10)
# memory usage: 384.4+ KB

# %%
# I don't think the "Contact" is useful anymore as the links are all expired.
concatenated_df.drop(columns=['Contact'], inplace=True)

# %%
# drop missing values from kW
# Change the missing value in "City" to "NA"
concatenated_df.dropna(subset=['kW'], inplace=True)
concatenated_df.loc[concatenated_df['City'].isna(), 'City'] = "NA"

# %%
concatenated_df.isna().sum()
# Out:
# Make                   0
# Model                  0
# Trim                   0
# Year                   0
# Mileage(km)            0
# kW                     0
# Fuel type              0
# Body type              0
# Color                100
# Transmission           0
# Emission standard      0
# Country                0
# City                   0
# Price(EUR)             0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
concatenated_df['Make'].unique()
# Out:
# array(['Volkswagen', 'Audi', 'Porsche', 'Alfa Romeo', 'Bmw', 'Ford',
#        'Peugeot', 'Mercedes Benz', 'Jeep', 'Hyundai', 'Škoda', 'Fiat',
#        'Mazda', 'Seat', 'Toyota', 'Citroen', 'Renault', 'Kia', 'Volvo',
#        'Opel', 'Land Rover', 'Honda', 'Suzuki', 'Saic', 'Lexus', 'Smart',
#        'Nissan', 'Jaguar', 'Mitsubishi', 'Abarth', 'Mini', 'Mclaren',
#        'Cupra', 'Ssangyong', 'Maserati', 'Subaru', 'Dodge', 'Chevrolet',
#        'Lancia', 'Bentley', 'Hummer', 'Dacia', 'Tesla', 'Ds Automobiles',
#        'Alpine', 'Ferrari', 'Isuzu', 'Dr', 'Rolls Royce', 'Chrysler',
#        'Lamborghini', 'Saab', 'Alpina', 'Cadillac', 'Ineos', 'Karma',
#        'Lincoln'], dtype=object)

# %%
concatenated_df['Model'].unique()
# Out:
# array(['Sharan', 'A6', 'Cayenne', 'Passat', 'Giulietta', 'X3', 'Mondeo',
#        '2008', 'C-Class', 'Renegade', 'I30', 'Z4', 'A4 Allroad', 'Focus',
#        'E-Class', '3 Series', 'Golf', 'Fabia', 'Tipo', '6', 'Q7', '308',
#        'Leon', 'Touran', 'Talento', 'Grand C-Max', 'C-Hr', 'C4 Cactus',
#        'Ecosport', 'Trafic', 'Octavia', 'X5', 'C4 Spacetourer',
#        '5 Series', 'Tiguan', 'Karoq', 'A4', 'X1', 'Sportage', '3',
#        'Cx-60', 'Transit Custom', 'Caddy', 'S60', 'Cc', 'A3', 'Q5',
#        'Scala', 'Superb', 'Zafira', 'A5', 'Exeo', 'C4 Picasso', 'Evoque',
#        'Galaxy', 'Mokka', 'Ix35', 'Arona', 'Kamiq', '3008', 'Antara',
#        'Hr-V', 'Xc60', 'Sx4 S-Cross', 'Berlingo', 'Discovery', 'Insignia',
#        'C-Max', 'Mg5', 'Cx-5', 'Lc', 'Vito', '4 Series', 'Citan',
#        'Espace', 'A8', 'Kuga', 'Forfour', 'C4', 'Stelvio', 'Ioniq',
#        'Panda', 'Micra', 'Transporter', 'V40', 'Mito', 'Twingo', 'Giulia',
#        'I10', 'Ateca', 'I-Pace', 'Qashqai', '7 Series', 'Q8', 'Asx', 'I8',
#        'Edge', 'Range Rover', 'Puma', '508', 'A1', 'Q2', 'V60', 'Taycan',
#        'Rsq8', 'S-Max', 'Q3', '595', 'Eqe', 'Kona', 'Cooper', 'Panamera',
#        '991', 'Rs6', 'Marvel R', 'Macan', 'Eqc', 'G-Class', 'Tt', 'A7',
#        'Gt', 'Tucson', 'Sq7', 'Formentor', 'Amg Gt', 'T-Roc', '911',
#        'Touareg', 'Megane', 'X-Trail', 'E-Pace', 'Range Rover Sport',
#        'Glc-Class', 'Defender', '5008', 'Korando', 'Xc40',
#        'Mustang Mach-E', 'Id.4', 'Polo', 'A-Class', 'Rcz', 'Astra',
#        'Ranger', 'Levante', 'Sl-Class', 'C5 Aircross', 'I3', 'Xc90',
#        'Gla-Class', 'Discovery Sport', 'Range Rover Velar', 'Compass',
#        'Mustang', '208', 'Kadjar', 'Gle-Class', 'Forester', 'Challenger',
#        'Grand Cherokee', '1 Series', 'A6 Allroad', 'Cl-Class', 'Optima',
#        'Altea', 'Roomster', 'Gls-Class', 'Rc-F', 'X6', 'Land Cruiser',
#        'X7', 'Civic', '8 Series', 'Cls-Class', 'Kodiaq', 'Cx-3',
#        'S-Class', 'Freemont', 'Colorado', 'S80', 'Outback', 'Sq5',
#        'Golf Plus', 'Tiguan Allspace', 'Cherokee', 'Countryman',
#        'Grand Vitara', 'Captiva', 'Fiesta', 'Thema', 'Clubman', 'V70',
#        'V50', 'Amarok', 'Levorg', 'Fluence', 'C3', 'Continental Gt',
#        'Enyaq', 'Ml-Class', 'H2', 'B-Class', 'V60 Cross Country',
#        'Santa Fe', 'Outlander', 'Stinger', 'Eqs', 'Rx-8', 'Duster',
#        'Yeti', 'Pathfinder', 'Sorento', '6 Series', 'S7', '5', 'Juke',
#        'Model 3', 'Stonic', 'Vitara', 'I20', 'Picanto', 'Xf', 'Eqb',
#        'T-Cross', 'Verso', '2 Series', 'C3 Aircross', '718',
#        'Lodgy Stepway', 'Ix3', 'Auris', 'Up!', 'Crossland X',
#        'Mx-5 Miata', 'Model Y', 'Leaf', 'Aygo X', 'Rav4', 'Expert',
#        'Clk-Class', 'Grand Scenic', 'Citigo', 'Jazz', 'Aygo', 'Vivaro',
#        'S8', 'Partner', '407', 'Sandero Stepway', 'Xceed', 'Eqa', 'Rio',
#        'Rx', 'Nx', 'Zafira Tourer', 'C3 Picasso', 'Model S', 'Rc', 'Ux',
#        'X4', 'Spacetourer', 'Grandland X', 'Ibiza', 'Niro', 'Scenic',
#        'Ds 7 Crossback', 'A110', 'Slk-Class', '500 X', '500c', 'S4',
#        'F-Type', 'Flying Spur', 'S3', 'Dokker', 'C1', '2', 'Cr-V', 'Cr-Z',
#        'Venga', '500', 'F355', 'V90', 'Is', 'S-Type', 'Alhambra', 'S5',
#        'Sandero', 'Wrangler', 'D-Max', 'Clio', 'M5', 'Combo', 'F-Pace',
#        'Arteon', 'Taigo', 'Jumper', 'Cx-30', 'Transit', 'Soul', '300',
#        'Torres', 'Corolla', 'Eqs Suv', 'Talisman', 'X2', '5.0', 'One',
#        'Trax', 'H3', 'Thesis', 'V40 Cross Country', 'Navara', 'Ghibli',
#        'Boxster', 'Grande Punto', 'Captur', 'Cayman', '500l', 'Ypsilon',
#        'Wraith', 'Cx-7', 'Ds5', 'Note', 'Corsa', 'Cruze', 'Ds4',
#        'Grandis', '108', 'Pulsar', 'Baleno', '107', 'Space Star', 'Xj',
#        'Grand Voyager', 'Beetle', 'Ceed', 'S6', 'E-2008', 'E-Golf',
#        'Prius', 'F Series', 'Pajero', 'Model X', 'Urban Cruiser', 'Hilux',
#        'Rs4', 'Land Cruiser V8', 'Jetta', '307 Cc', 'X4m', 'Avensis',
#        'Ram 1500', 'Granturismo', 'Aventador', 'R-Class', '4008',
#        'Excursion', '9-3', 'Ev6', 'B7', 'Rexton', 'Accord',
#        'Eclipse Cross', 'Kizashi', 'Modus', 'Xv', 'Aveo', 'C5', 'Rapid',
#        '159', 'Yaris', 'Lancer', 'I40', 'Meriva', 'Tiida', 'Lodgy',
#        'Elantra', 'Bravo', 'Tivoli', 'Delta', 'Koleos', 'Zoe', 'Maverick',
#        'Proace', 'Jumpy', 'Kangoo', 'Logan Mcv', 'Master', 'Arkana',
#        'Portofino M', 'Ct6', 'M3', 'Accent', 'Grenadier', 'Adam',
#        'C-Elysee', 'Logan', 'Rs5', 'Movano', 'Laguna', 'Bayon', 'Velar',
#        'Tonale', 'Ds 3 Crossback', 'Tarraco', 'Passat Alltrack', 'Sq2',
#        'Scirocco', '207 Cc', 'Quattroporte', 'Justy', 'Jimny', 'S40',
#        '570s', 'Rs7', 'Murano', 'Tourneo Custom', 'Legacy', 'Orlando',
#        'Impreza', '308 Cc', 'Carens', 'Revero', 'Charger', 'Xc70', 'Eos',
#        'Rsq3', 'Navigator', 'Rs3'], dtype=object)

# %%
#  convert to lowercase
concatenated_df['Trim'] = concatenated_df['Trim'].str.lower()

# %%
concatenated_df['Trim'].value_counts()
# Out:
# Trim
# 2.0                             294
# 1.6                             204
# 1.2                             139
# 1.0                             124
# 1.0 tsi                         100
# 1.5                              91
# 2.0 tdi                          84
# 1.2 puretech                     84
# 1.4                              75
# 1.6 tdi                          53
# 3.0                              51
# 1.5 dci                          49
# 1.0 ecoboost                     44
# 1.3                              42
# 2.0 tdci                         39
# 1.8                              39
# 1.5 bluehdi                      37
# electro                          37
# 1.5 tsi                          37
# 1.6 gdi                          26
# 450h                             25
# 2.5                              25
# 3.0 tdi                          23
# 2.2                              21
# xdrive20d                        20
# xdrive30d                        20
# 1.1                              18
# 1.2 tsi                          18
# 1.6 t-gdi                        17
# 1.4 tsi                          17
# 1.0 t-gdi                        15
# 2.4                              15
# 520d                             15
# 200                              15
# 4.0                              15
# 1.5 35 tfsi                      14
# 1.0 dig-t                        13
# 320d                             13
# 1.0 30 tfsi                      13
# 2.0 tsi                          12
# 2.0 ecoblue                      12
# 0.0 performance                  12
# 0.0 long range                   11
# 0.9                              11
# 2.0 t8                           11
# 2.2 d                            11
# 3.0 50 tdi quattro               10
# 350                              10
# 1.0 tce                          10
# 1.6 hdi                          10
# 1.3 dig-t                        10
# d                                 9
# 2.0 d                             9
# 1.2 vti                           9
# 1.6 crdi                          9
# 3.0 crd                           9
# 1.6 multijet                      9
# 1.6 thp                           9
# 5.0                               9
# 1.4 tfsi                          9
# 2.0 tdi 4motion                   9
# 2.4 d5                            9
# 2.0 35 tdi                        9
# 320d xdrive                       9
# 1.6 dci                           8
# acenta                            8
# 2.0 d3                            8
# 220 d                             8
# 1.5 tdci                          8
# 1.7                               8
# sdrive18d                         8
# 1.5 ecoboost                      7
# 1.6 bluehdi                       7
# 0.9 tce                           7
# 250                               7
# 1.0 tsi dsg                       7
# 2.2 hdi                           7
# 2.0 tdi quattro                   7
# 2.0 d4                            7
# 3.0 diesel                        7
# 3.0 tdv6                          7
# 3.0 tdi quattro                   7
# 63 amg                            7
# 318d                              7
# 2.7                               7
# 1.7 dci                           7
# 3.0 d                             6
# 3.0 50 tdi                        6
# 2.0 45 tfsi                       6
# xdrive40d                         6
# 1.0 sce                           6
# 2.4 d4 awd                        6
# 55 amg                            6
# m50d                              6
# 2.0 tsi vz                        6
# 2.3                               6
# 3.0 tdi v6                        6
# 1.0 25 tfsi                       6
# 3.0 s                             6
# 2.0 bluehdi                       6
# 1.9                               6
# 1.2 turbo                         6
# m40d                              6
# 2.0 .35 tdi                       5
# 2.2 crdi                          5
# 300                               5
# 2.0 dci                           5
# 1.2 tce                           5
# 30d                               5
# 2.0 t5 awd                        5
# 43 amg                            5
# 2.0 tfsi                          5
# 400                               5
# 4.4                               5
# 1.2 tfsi                          4
# 180                               4
# 3.2                               4
# 2.0 rs tdi                        4
# 2.0 35                            4
# 1.7 crdi                          4
# 525i                              4
# 0.0 range standard                4
# 450h+                             4
# 1.6 d                             4
# 3.0 sdv6                          4
# 0.9 twinair                       4
# 1.0 vti                           4
# 3.6                               4
# 330i                              4
# 2.0 tsi cupra                     4
# 2.8                               4
# 2.5 turbo                         4
# 1.5 ecoblue                       4
# 4.0 tdi                           4
# 1.0 ecoboost titanium             4
# 2.5 t5                            4
# 2.0 d4 awd                        4
# 300h                              4
# 1.3 tce                           4
# 1.6 vvt-i                         4
# 2.0 skyactiv                      4
# 2.0 hdi                           4
# 1.6 puretech                      4
# 2.9                               4
# 4s                                4
# 2.0 t6 awd                        4
# 6.4 srt8                          4
# 1.0 tfsi                          4
# 1.2 tdi                           4
# 1.5 hdi                           4
# 2.4 d5 awd                        4
# 2.2 cd                            4
# 1.0 dsg tsi                       4
# 6.0                               3
# 40d                               3
# 3.6 turbo                         3
# 2.8 cupra                         3
# 580                               3
# 3.8 4s                            3
# 220i                              3
# 520d xdrive                       3
# 300e                              3
# 6.0 w12                           3
# 1.6 s                             3
# xdrive40i                         3
# 2.0 320                           3
# 40i                               3
# 2.0 dsg tdi                       3
# 530d xdrive                       3
# 2.0 gti                           3
# 3.8                               3
# 2.0 40 tdi                        3
# 2.0 t4                            3
# m850i xdrive                      3
# 730d                              3
# 118d                              3
# 320i                              3
# 2.0 titanium                      3
# 1.8 tfsi                          3
# 1.8 vvt-i                         3
# 4.8 turbo                         3
# xdrive20i                         3
# 1.0 limited                       3
# 20d                               3
# 2.0 d-4d                          3
# 3.3                               3
# tekna                             3
# sdrive18i                         3
# i                                 3
# 1.0 titanium                      3
# 1.0 ecoboost st                   3
# 1.5 t5 recharge                   3
# f                                 3
# 530e                              3
# 1.5 etsi                          3
# 3.0 tfsi                          3
# 1.9 tdi                           3
# 220                               3
# 500 4matic                        3
# 30d xdrive                        3
# 1.3 i-vtec                        2
# 1.5 35 tfsi s tronic              2
# 2.0 b4                            2
# 220d                              2
# 1.2 mpi                           2
# 2.8 crd                           2
# 1.4 tfsi ultra                    2
# 3.0 320                           2
# 1.6 cdti                          2
# 1.0 mpi                           2
# 1.5 t3                            2
# 2.0 40 tfsi                       2
# 1.8 t                             2
# 280                               2
# 1.5 i-mmd                         2
# 3.7 350 sl                        2
# xdrive23d                         2
# 530i                              2
# 2.9 turbo                         2
# 2.0 tfsi quattro                  2
# 2.4 d3                            2
# 3.0 350                           2
# 25e xdrive                        2
# 418d                              2
# 3.5                               2
# 1.8 hybrid                        2
# 1.4 gte                           2
# gt 77 kwh                         2
# 1.6 jtdm                          2
# turbo                             2
# 1.4 ltz                           2
# 4.0 tfsi                          2
# 500                               2
# 320d efficientdynamics            2
# 2.0 cdti                          2
# premium                           2
# 2.0 t8 awd                        2
# gt                                2
# 2.0 recharge t8                   2
# 2.0 30 tdi                        2
# 4.0 tfsi v8                       2
# 2.0 recharge t6                   2
# 4.0 amg 55                        2
# 40 kwh                            2
# 1.2 s tfsi                        2
# 4.1 tdi                           2
# 4.0 turbo                         2
# 2.0 d5 awd                        2
# 6.4                               2
# 2.0 crdi                          2
# 4.5                               2
# 1.0 shine                         2
# 350 cdi                           2
# 2.0 sdrive20i                     2
# 250 cdi be                        2
# 2.0 st                            2
# 1.0 turbo                         2
# 2.0 tdi scr                       2
# 220 cdi                           2
# 280 cdi                           2
# 316d                              2
# 530d                              2
# xdrive18d                         2
# 2.0 tdi ultra                     2
# 18d                               2
# 1.6 30 tdi                        2
# 2.8 vr6                           2
# n-connecta                        2
# 1.0 st                            2
# 1.6 drive                         2
# 1.0 fr tsi                        2
# 320                               2
# 2.0 mjet                          2
# 750i                              2
# 1.4 d-4d                          2
# 2.5 dci                           2
# 320 cdi                           2
# 2.0 r                             2
# 4.8 s                             2
# 2.3 ecoboost                      2
# 3.3 t-gdi                         2
# 1.5 tgi                           2
# 2.0 4x4 dsg tsi                   2
# 1.6 vti                           2
# 2.0 40 tdi quattro s tronic       2
# 3.4                               2
# 218i                              2
# m sport                           2
# 420d                              2
# e+ 62 kwh                         2
# 420i                              2
# 1.3 mjet                          2
# 2.0 tsi 4motion                   2
# 2.9 s                             2
# 740d xdrive                       2
# 1.4 tdi                           2
# 2.0 4x4 dsg tdi                   2
# 1.0 fr                            1
# 3.6 4                             1
# 1.4 vti                           1
# 2.4 d4                            1
# 335d xdrive                       1
# 5.0 v10                           1
# 750li xdrive                      1
# 1.9 t4                            1
# 130i                              1
# 2.0 tdi bluemotion                1
# m550d xdrive                      1
# 325xi                             1
# 5.7                               1
# 400 cdi                           1
# 200d                              1
# 535d                              1
# 65 amg                            1
# 2.2 220d                          1
# 4.8 4s                            1
# 6.5 lp 700-4                      1
# 2.0 d5                            1
# 2.4 sport                         1
# 525d                              1
# 3.2 did                           1
# 4.7                               1
# 418i                              1
# 4.6 gt                            1
# 1.4 fsi                           1
# 330e                              1
# 320i xdrive                       1
# 3.6 gts                           1
# 2.1 d                             1
# 1.6 hybrid                        1
# 3.0 p380                          1
# 2.5 d5                            1
# 1.5 ddis                          1
# 2.0 p250                          1
# 1.6 nismo                         1
# 1.6 cooper s                      1
# 2.0 tfsi s tronic                 1
# 1.3 vvt-i                         1
# 4.9                               1
# 2.8 turbo                         1
# 30i sdrive                        1
# 3.0 s q4                          1
# 335i                              1
# 440i                              1
# 3.0 45 tdi quattro                1
# 3.0 dct                           1
# 3.5 v6                            1
# 2.0 t5                            1
# 5.6                               1
# 540i                              1
# 2.5 tfsi                          1
# 5.0 gt                            1
# 2.0 fsi                           1
# 2.0 e-boxer                       1
# 250d 4matic                       1
# 5.7 v8                            1
# 3.0 s e-hybrid                    1
# 1.9 d                             1
# 3.0 e-hybrid                      1
# 53 amg 4matic                     1
# 640i                              1
# 2.1                               1
# 350d 4matic                       1
# 550i xdrive                       1
# 2.0 tsi 4drive                    1
# 2.7 tdi                           1
# 160                               1
# 3.9                               1
# 1.5 hybrid                        1
# 220d 4matic                       1
# 1.8 skyactiv-d                    1
# 1.2 jtd                           1
# ze 50                             1
# 116d                              1
# 2.4 phev                          1
# 18i sdrive                        1
# 4.8                               1
# 1.9 ttid                          1
# 6.8 v10                           1
# 2.2 tdci                          1
# 435d xdrive                       1
# 330xd                             1
# 400 4matic                        1
# 740d                              1
# 3.0 cs                            1
# 2.0 2.0                           1
# 2.0 40 tfsi quattro               1
# 20i xdrive                        1
# 2.4 awd d5                        1
# 1.5 d                             1
# 2.0 2.0 dsg tdi                   1
# sdrive20i                         1
# 2.0 tdi s-tronic                  1
# 840d xdrive                       1
# 500 sl                            1
# 2.0 d180                          1
# 2.0 xcellence tdi 4drive          1
# 550                               1
# 2.0 2.0 4x4 dsg tdi               1
# 2.2 i4                            1
# 1.5 one d                         1
# 18d sdrive                        1
# 5.2 fsi v10                       1
# 350 sl                            1
# 3.8 v6                            1
# 2.0 2.0 tdi                       1
# 2.5 crd                           1
# 2.0 sd                            1
# 1.9 ddis                          1
# 428 gran coupe                    1
# 350 l                             1
# 2.3 rs                            1
# 4.0 v8 s                          1
# 300d                              1
# m440i xdrive                      1
# 400d 4matic                       1
# 200 cdi                           1
# xdrive35i                         1
# 2.3 did                           1
# 2.0 4x4 dsg rs                    1
# 525d xdrive                       1
# m50i xdrive                       1
# 2.5 crdi                          1
# 640d xdrive                       1
# 3.0 targa 4                       1
# 2.0 t                             1
# 4.2 tdi                           1
# 328i                              1
# 420d xdrive                       1
# 4.0 cayman gt4                    1
# 1.6 limited                       1
# electric                          1
# visia                             1
# amg43                             1
# m40i xdrive                       1
# sdrive20d                         1
# 330i xdrive                       1
# 3.0 t6                            1
# 3.5 450h                          1
# 250 d                             1
# 200 cgi be                        1
# 1.6 multijet l2h1                 1
# xdrive35d                         1
# 2.0 fr                            1
# 2.0 ecojet l2h1                   1
# 500h                              1
# 111 cdi                           1
# 330d                              1
# 435 gran coupe                    1
# 420 gran coupe                    1
# style                             1
# 325d                              1
# 3.7                               1
# ev400s                            1
# 1.4 competizione                  1
# 2.2 crd                           1
# 4.0 r                             1
# pro                               1
# 4.0 tfsi quattro tiptronic        1
# 45 amg                            1
# 1.4 d                             1
# 16d                               1
# 2.0 520d                          1
# 0.6                               1
# 1.4 turismo                       1
# 450 amg 4matic                    1
# 2.0 i                             1
# 4.0 tdi v8                        1
# 125i                              1
# 3.0 d-4d                          1
# 430d                              1
# 35 amg                            1
# 1.2 d tce                         1
# 3.6 carrera                       1
# 2.0 40 tdi quattro                1
# 225d                              1
# 300 4matic                        1
# 1.8 250                           1
# 2.0 300 4matic                    1
# 4.0 unlimited                     1
# 4.1 diesel                        1
# 3.0 50 tdi quattro tiptronic      1
# 1.4 t-jet                         1
# 2.4 limited                       1
# 1.7 cdti                          1
# 3.4 s                             1
# 2.2 cdti                          1
# 6.6                               1
# 2.7 tdi v6 quattro tiptronic      1
# 2.0 30                            1
# 4.0 500 g                         1
# 2.7 tdv6                          1
# 5.0 tdi                           1
# 2.0 xdrive                        1
# 2.3 sport                         1
# 2.0 bluehdi hdi                   1
# 2.0 45 tfsi quattro s tronic      1
# 1.0 s tfsi                        1
# 1.2 dsg tsi                       1
# 123d                              1
# 1.4 tsi act                       1
# m135i                             1
# 645ci                             1
# 2.8 fsi                           1
# 2.7 270                           1
# 2.4 jtd                           1
# 1.6 hybrid gdi                    1
# 300 h                             1
# 545e                              1
# 1.6 jcw                           1
# ev                                1
# 180d                              1
# 1.5 2.0 4x4 scr tdi               1
# 0.0 plus standard                 1
# 350h                              1
# 1.0 tdi                           1
# 200 k                             1
# 1.1 ti-vct                        1
# 5.0 p450                          1
# 1.6 sce                           1
# 2.0 35 tfsi                       1
# 1.5 i-vtec                        1
# 2.0 skyactiv-g                    1
# 3.7 luxury                        1
# 250 sport                         1
# 2.0 i-mmd e:hev                   1
# 250 4matic                        1
# 4.4 v8                            1
# 350d                              1
# 43 amg 4matic                     1
# 840ci                             1
# 2.5 i sport                       1
# 1.5 sdrive18i                     1
# 2.9 350                           1
# 1.6 i-dtec                        1
# 1.4 vz                            1
# 2.0 type r                        1
# 5.5 55 amg sl                     1
# tfsi                              1
# Name: count, dtype: int64

# %%
concatenated_df.head(20)
# Out:
#              Make       Model         Trim  Year  Mileage(km)     kW  \
# 0      Volkswagen      Sharan      2.0 tdi  2013       182000  104.0
# 1            Audi          A6          2.7  2009       250000  141.0
# 2         Porsche     Cayenne   3.0 diesel  2011       256000  182.0
# 3      Volkswagen      Passat  2.0 tdi scr  2019        94187  111.0
# 4      Volkswagen      Passat  2.0 tdi scr  2019        77167  111.0
# 5      Alfa Romeo   Giulietta          1.4  2012       166300  126.0
# 6             Bmw          X3            d  2005       179000  162.0
# 7            Ford      Mondeo     2.0 tdci  2018       107000  111.0
# 8            Ford      Mondeo     2.0 tdci  2018       105000  111.0
# 9      Volkswagen      Sharan      2.0 tdi  2015       159000  111.0
# 10        Peugeot        2008      1.6 hdi  2015       126116   89.0
# 11  Mercedes Benz     C-Class      220 cdi  2010       221000  126.0
# 12           Jeep    Renegade          2.0  2015       160000   89.0
# 13            Bmw          X3    xdrive20d  2012       148000  137.0
# 14  Mercedes Benz     C-Class      220 cdi  2011       221000  126.0
# 15        Hyundai         I30          1.0  2019        53200   89.0
# 16            Bmw          Z4            i  2008       109000  131.0
# 17           Audi  A4 Allroad      2.0 tdi  2012       214000  131.0
# 18            Bmw          X3    xdrive20d  2013       170000  137.0
# 19           Ford       Focus     1.5 tdci  2017       156000   89.0
#
#    Fuel type    Body type   Color Transmission  Emission standard  Country  \
# 0     Diesel          Van    Gray       Manual                  5  Austria
# 1     Diesel        Sedan  Silver       Manual                  5  Austria
# 2     Diesel          Suv   Black    Automatic                  5  Austria
# 3     Diesel        Wagon  Silver       Manual                  6  Austria
# 4     Diesel        Wagon   Black    Automatic                  6  Austria
# 5     Petrol        Sedan     Red    Automatic                  5  Austria
# 6     Diesel          Suv  Silver    Automatic                  4  Austria
# 7     Diesel        Wagon    Gray    Automatic                  6  Austria
# 8     Diesel        Wagon   White    Automatic                  6  Austria
# 9     Diesel          Van   Black    Automatic                  6  Austria
# 10    Diesel    Crossover    Gray       Manual                  6  Austria
# 11    Diesel        Sedan   Black    Automatic                  5  Austria
# 12    Diesel    Crossover   White       Manual                  6  Austria
# 13    Diesel          Suv   Black    Automatic                  5  Austria
# 14    Diesel        Sedan   Black    Automatic                  5  Austria
# 15    Petrol        Wagon   Brown       Manual                  6  Austria
# 16    Petrol  Convertible   Black       Manual                  4  Austria
# 17    Diesel    Crossover   Brown       Manual                  5  Austria
# 18    Diesel          Suv   Black    Automatic                  5  Austria
# 19    Diesel        Wagon  Silver       Manual                  6  Austria
#
#               City  Price(EUR)
# 0   Braunau Am Inn     15499.0
# 1         Salzburg      8900.0
# 2   Braunau Am Inn     25999.0
# 3        Wolfsberg     18790.0
# 4             Wels     18990.0
# 5             Linz      7990.0
# 6             Linz      9900.0
# 7            Steyr     17850.0
# 8            Steyr     17850.0
# 9         Salzburg     18450.0
# 10       Amstetten      9940.0
# 11  Braunau Am Inn     10499.0
# 12        Salzburg     15900.0
# 13        Lustenau     19950.0
# 14  Braunau Am Inn     11999.0
# 15            Linz     15490.0
# 16           Steyr     15499.0
# 17        Salzburg     13990.0
# 18  Braunau Am Inn     18499.0
# 19           Steyr     12450.0

# %%
concatenated_df.to_csv('europe_offers_01.csv', index= False)

# %%
concatenated_df.shape
# Out:
# (3279, 14)
